# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import boxcox

# %%
cruise_ship = pd.read_excel("C:/Users/Lenovo/OneDrive/Desktop/Data-Science-Program/DATASETS/cruise_ship.xlsx")

# %%
pd.options.display.max_columns = None
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %% [markdown]
# Examine all Columns for Normality

# %%
sns.pairplot(cruise_ship)

# %%
sns.pairplot(cruise_ship)

# %% [markdown]
# TONNAGE SQRT went to far over

# %%
cruise_ship['TonnageSQRT'] = np.sqrt(cruise_ship['Tonnage'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG
# 0     42.64     329   174.002874   10.318144
# 1     42.64     329   174.002874   10.318144
# 2     31.80     453   217.398252   10.763462
# 3     36.99     892   331.662479   11.608236
# 4     38.36     740   318.359859   11.526365

# %%
cruise_ship['TonnageSQRT'] = np.sqrt(cruise_ship['Tonnage'])

# %%
cruise_ship['TonnageLOG'] = np.log(cruise_ship['Tonnage'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG
# 0     42.64     329   174.002874   10.318144
# 1     42.64     329   174.002874   10.318144
# 2     31.80     453   217.398252   10.763462
# 3     36.99     892   331.662479   11.608236
# 4     38.36     740   318.359859   11.526365

# %%
cruise_ship.TonnageLOG.hist()
# Out:
# <Axes: >

# %% [markdown]
# cabins

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG
# 0     42.64     329   174.002874   10.318144
# 1     42.64     329   174.002874   10.318144
# 2     31.80     453   217.398252   10.763462
# 3     36.99     892   331.662479   11.608236
# 4     38.36     740   318.359859   11.526365

# %%
cruise_ship['CabinsSQRT'] = np.sqrt(cruise_ship['Cabins'])

# %% [raw]
# cruise_ship.head()

# %%
cruise_ship.CabinsSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# passengers

# %%
cruise_ship['passngrsSQRT'] = np.sqrt(cruise_ship['passngrs'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  passngrsSQRT
# 0     42.64     329   174.002874   10.318144   18.841444     26.343880
# 1     42.64     329   174.002874   10.318144   18.841444     26.343880
# 2     31.80     453   217.398252   10.763462   27.258026     38.548671
# 3     36.99     892   331.662479   11.608236   38.574603     54.534393
# 4     38.36     740   318.359859   11.526365   36.345564     51.400389

# %%
cruise_ship.passngrsSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# crew

# %%
cruise_ship['CrewSQRT'] = np.sqrt(cruise_ship['Crew'])

# %%
cruise_ship.CrewSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# PassScpr

# %%
cruise_ship['PassSpcRSQRT'] = np.sqrt(cruise_ship['PassSpcR'])

# %%
cruise_ship.PassSpcRSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# OUTCAB

# %% [markdown]
# went to far

# %%
cruise_ship['outcabSQRT'] = np.sqrt(cruise_ship['outcab'])

# %%
cruise_ship.outcabSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# OUTCAB LOG

# %%
cruise_ship['outcabLOG'] = np.log(cruise_ship['outcab'])

# %%
cruise_ship.outcabLOG.hist()
# Out:
# <Axes: >

# %% [markdown]
# # Transform Negatively Skewed Data

# %% [markdown]
# YEAR BUILT

# %%
cruise_ship['YearBltSQ'] = cruise_ship['YearBlt']**2

# %%
cruise_ship.YearBltSQ.hist()
# Out:
# <Axes: >

# %%
cruise_ship['YearBltCUBE'] = cruise_ship['YearBlt']**3'] = cruise_ship['YearBlt']**3

# %%
cruise_ship.YearBltCUBE.hist()
# Out:
# <Axes: >

# %% [markdown]
# length
# use sqrt
# cube goes to far

# %%
cruise_ship['LengthSQ'] = cruise_ship['Length']**2

# %%
cruise_ship.LengthSQ.hist()
# Out:
# <Axes: >

# %%
cruise_ship['LengthCUBE'] = cruise_ship['Length']**3

# %%
cruise_ship.LengthCUBE.hist()
# Out:
# <Axes: >
