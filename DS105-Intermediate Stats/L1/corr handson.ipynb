# %% [markdown]
# correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
power_lifting = pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/Data-Science-Program/DATASETS/power_lifting.csv")

# %%
power_lifting.head
# Out:
# <bound method NDFrame.head of         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 386409    8481   William Barabas   M   Multi-ply   NaN        Elite
# 386410    8481      Justin Zottl   M   Multi-ply   NaN        Elite
# 386411    8481     Jake Anderson   M   Multi-ply   NaN        Elite
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN        Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN        Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# ...

# %%
power_lifting1 = power_lifting.drop(['Name', 'Sex', 'Equipment', 'Division'], axis=1)

# %%
power_lifting1.head
# Out:
# <bound method NDFrame.head of         MeetID   Age  BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  \
# 0            0  47.0         59.60            60       NaN        47.63
# 1            0  42.0         58.51            60       NaN       142.88
# 2            0  42.0         58.51            60       NaN       142.88
# 3            0  42.0         58.51            60       NaN          NaN
# 4            0  18.0         63.68          67.5       NaN          NaN
# ...        ...   ...           ...           ...       ...          ...
# 386409    8481   NaN        113.58           125       NaN          NaN
# 386410    8481   NaN        119.02           125       NaN          NaN
# 386411    8481   NaN        120.29           125       NaN          NaN
# 386412    8481   NaN        126.73           140       NaN          NaN
# 386413    8481   NaN        129.46           140       NaN          NaN
#
# ...

# %%
power_lifting1['BestBenchKg'].corr(power_lifting1['BodyweightKg'])
# Out:
# 0.5844312818128131

# %%
power_lifting1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10880\451980136.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   power_lifting1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# <style type="text/css">
# #T_cfbaa_row0_col0, #T_cfbaa_row1_col1, #T_cfbaa_row2_col2, #T_cfbaa_row3_col3, #T_cfbaa_row4_col4, #T_cfbaa_row5_col5, #T_cfbaa_row6_col6, #T_cfbaa_row7_col7, #T_cfbaa_row8_col8, #T_cfbaa_row9_col9, #T_cfbaa_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cfbaa_row0_col1, #T_cfbaa_row7_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_cfbaa_row0_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_cfbaa_row0_col3, #T_cfbaa_row1_col2, #T_cfbaa_row5_col0, #T_cfbaa_row6_col10 {
# ...

# %%
power_lifting1.head
# Out:
# <bound method NDFrame.head of      YearBlt  Tonnage  passngrs  Length  Cabins  Crew  PassSpcR  outcab
# 0       2007    30277       694     594     355   355     42.64     329
# 1       2007    30277       694     594     355   355     42.64     329
# 2       1987    47262      1486     722     743   670     31.80     453
# 3       2002   110000      2974     953    1488  1910     36.99     892
# 4       1996   101353      2642     892    1321  1000     38.36     740
# ..       ...      ...       ...     ...     ...   ...       ...     ...
# 153     1991     3341        66     279      33    59     50.62      33
# 154     1999    76800      1960     879     967  1200     39.18     608
# 155     1988     5350       158     440      74    88     33.86      74
# 156     1986     5350       167     440      74    88     32.04      74
# 157     1990    14745       308     617     156   180     47.87     156
#
# [158 rows x 8 columns]>

# %% [markdown]
# Using .corr() on An Entire Dataset

# %%
cruise_ship1.corr(method='pearson')
# Out:
#            YearBlt   Tonnage  passngrs    Length    Cabins      Crew  \
# YearBlt   1.000000  0.606646  0.515542  0.532286  0.510019  0.530657
# Tonnage   0.606646  1.000000  0.945061  0.922368  0.948764  0.927569
# passngrs  0.515542  0.945061  1.000000  0.883535  0.976341  0.915234
# Length    0.532286  0.922368  0.883535  1.000000  0.889798  0.895857
# Cabins    0.510019  0.948764  0.976341  0.889798  1.000000  0.950823
# Crew      0.530657  0.927569  0.915234  0.895857  0.950823  1.000000
# PassSpcR  0.278830 -0.040846 -0.294867 -0.090488 -0.253181 -0.155509
# outcab    0.547203  0.921931  0.914551  0.901047  0.934136  0.900466
#
#           PassSpcR    outcab
# YearBlt   0.278830  0.547203
# Tonnage  -0.040846  0.921931
# passngrs -0.294867  0.914551
# Length   -0.090488  0.901047
# Cabins   -0.253181  0.934136
# Crew     -0.155509  0.900466
# PassSpcR  1.000000 -0.145602
# outcab   -0.145602  1.000000

# %%
cruise_ship1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_e55aa_row0_col0, #T_e55aa_row1_col1, #T_e55aa_row2_col2, #T_e55aa_row3_col3, #T_e55aa_row4_col4, #T_e55aa_row5_col5, #T_e55aa_row6_col6, #T_e55aa_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e55aa_row0_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e55aa_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e55aa_row0_col3, #T_e55aa_row0_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e55aa_row0_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e55aa_row0_col6, #T_e55aa_row1_col6, #T_e55aa_row2_col6, #T_e55aa_row3_col6, #T_e55aa_row4_col6, #T_e55aa_row5_col6, #T_e55aa_row6_col2, #T_e55aa_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e55aa_row0_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e55aa_row1_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_e55aa_row1_col2, #T_e55aa_row4_col7 {
# ...

# %%
sns.heatmap(cruise_ship1.corr(), annot=True)
# Out:
# <Axes: >
